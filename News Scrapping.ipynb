# %%
import time
import random
from selenium import webdriver
import csv
from selenium.webdriver.support.select import Select
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd
from bs4 import BeautifulSoup

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--incognito")

# %%
driver = webdriver.Chrome(executable_path=r'/Users/aniketmuluk/Downloads/chromedriver',chrome_options=chrome_options)

# %%
driver.get('https://www.nytimes.com/search/dow%20jones/newest')

# %%
#accesing SHOW MORE button and clicking it
show_more_button_area = driver.find_element_by_class_name("Search-showMore--Plid0")
show_more_button = show_more_button_area.find_element_by_tag_name('button')


for i in range(100):
    show_more_button.click()
    time.sleep(5)

# %%
Headlines = driver.find_element_by_class_name("SearchResults-main--3t9sI")

# %%
Headlines1 = Headlines.get_attribute('innerHTML')

# %%
soup_Headlines = BeautifulSoup(Headlines1,'html5lib')

# %%
Headlines2 = soup_Headlines.find_all('h4')

# %%
print(Headlines2)
# Out:
# [<h4 class="Item-headline--3WqlT">Business Highlights</h4>, <h4 class="Item-headline--3WqlT">How Major US Stock Indexes Fared Wednesday</h4>, <h4 class="Item-headline--3WqlT">Markets Right Now: Mixed Finish for US Stock Indexes</h4>, <h4 class="Item-headline--3WqlT">Wall Street Ekes Out Small Gain as Earnings Offset Cost Worries</h4>, <h4 class="Item-headline--3WqlT">Stocks Weaker for Fifth Day as U.S. 10-Year Debt Yield Tops 3 Percent</h4>, <h4 class="Item-headline--3WqlT">Stocks Close Mixed; Dow Industrials End a Losing Streak</h4>, <h4 class="Item-headline--3WqlT">Business Highlights</h4>, <h4 class="Item-headline--3WqlT">How Major US Stock Indexes Fared Tuesday</h4>, <h4 class="Item-headline--3WqlT">Caterpillar Shares Slide; Trump Steel Tariffs May Boost Costs</h4>, <h4 class="Item-headline--3WqlT">Grumpy Investors Can’t Find Anything to Look Forward To</h4>, <h4 class="Item-headline--3WqlT">Markets Right Now: Big Tech, Industrials Lead Stocks Lower</h4>, <h4 class="Item-headline
# ...

# %%
Main_headlines = []
for z in Headlines2:
    Main_headlines.append(z.get_text())

print(Main_headlines)
# Out:
# ['Business Highlights', 'How Major US Stock Indexes Fared Wednesday', 'Markets Right Now: Mixed Finish for US Stock Indexes', 'Wall Street Ekes Out Small Gain as Earnings Offset Cost Worries', 'Stocks Weaker for Fifth Day as U.S. 10-Year Debt Yield Tops 3 Percent', 'Stocks Close Mixed; Dow Industrials End a Losing Streak', 'Business Highlights', 'How Major US Stock Indexes Fared Tuesday', 'Caterpillar Shares Slide; Trump Steel Tariffs May Boost Costs', 'Grumpy Investors Can’t Find Anything to Look Forward To', 'Markets Right Now: Big Tech, Industrials Lead Stocks Lower', 'Wall Street Slides as High Bond Yields Fan Cost Worries', 'Washington Moves to Soften a Big Bank Capital Rule: DealBook Briefing', 'Asian Stocks Slip Following Sell-Off on Wall Street', 'Business Highlights', 'How Major US Stock Indexes Fared Monday', 'Markets Right Now: Stocks End Lower After Early Gain Fades', 'Wall Street Ends Mixed as Investors Eye Earnings', "Australia's Myer Names Ex-House of Fraser Head as Ne
# ...

# %%
Dates = soup_Headlines.find_all('time')

# %%
print(Dates)
# Out:
# [<time class="Item-date--Ocvr2">1h ago</time>, <time class="Item-date--Ocvr2">2h ago</time>, <time class="Item-date--Ocvr2">2h ago</time>, <time class="Item-date--Ocvr2">1h ago</time>, <time class="Item-date--Ocvr2">2h ago</time>, <time class="Item-date--Ocvr2">1h ago</time>, <time class="Item-date--Ocvr2">April 24</time>, <time class="Item-date--Ocvr2">April 24</time>, <time class="Item-date--Ocvr2">April 24</time>, <time class="Item-date--Ocvr2">April 24</time>, <time class="Item-date--Ocvr2">April 24</time>, <time class="Item-date--Ocvr2">April 24</time>, <time class="Item-date--Ocvr2">April 24</time>, <time class="Item-date--Ocvr2">April 24</time>, <time class="Item-date--Ocvr2">April 23</time>, <time class="Item-date--Ocvr2">April 23</time>, <time class="Item-date--Ocvr2">April 23</time>, <time class="Item-date--Ocvr2">April 23</time>, <time class="Item-date--Ocvr2">April 23</time>, <time class="Item-date--Ocvr2">April 23</time>, <time class="Item-date--Ocvr2">April 21</time>, <
# ...

# %%
Main_dates = []
for d in Dates:
    Main_dates.append(d.get_text())

print(Main_dates)
# Out:
# ['1h ago', '2h ago', '2h ago', '1h ago', '2h ago', '1h ago', 'April 24', 'April 24', 'April 24', 'April 24', 'April 24', 'April 24', 'April 24', 'April 24', 'April 23', 'April 23', 'April 23', 'April 23', 'April 23', 'April 23', 'April 21', 'April 20', 'April 20', 'April 20', 'April 20', 'April 20', 'April 20', 'April 19', 'April 19', 'April 20', 'April 19', 'April 19', 'April 18', 'April 18', 'April 18', 'April 18', 'April 17', 'April 17', 'April 17', 'April 17', 'April 17', 'April 16', 'April 16', 'April 17', 'April 16', 'April 16', 'April 16', 'April 15', 'April 13', 'April 13', 'April 13', 'April 13', 'April 13', 'April 13', 'April 13', 'April 12', 'April 12', 'April 12', 'April 12', 'April 12', 'April 9', 'April 6', 'April 6', 'April 4', 'April 5', 'March 30', 'March 29', 'March 27', 'March 27', 'March 26', 'March 23', 'March 22', 'March 20', 'March 14', 'March 14', 'March 9', 'March 7', 'March 7', 'March 6', 'Feb. 26', 'Feb. 22', 'Feb. 15', 'Feb. 14', 'Feb. 13', 'Feb. 12', 'Feb
# ...

# %%
News_df = pd.DataFrame({'Headline':Main_headlines,'Date':Main_dates})

# %%
print(News_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1008 entries, 0 to 1007
# Data columns (total 2 columns):
# Date        1008 non-null object
# Headline    1008 non-null object
# dtypes: object(2)
# memory usage: 15.8+ KB
# None

# %%
News_df
# Out:
#                 Date                                           Headline
# 0             1h ago                                Business Highlights
# 1             2h ago         How Major US Stock Indexes Fared Wednesday
# 2             2h ago  Markets Right Now: Mixed Finish for US Stock I...
# 3             1h ago  Wall Street Ekes Out Small Gain as Earnings Of...
# 4             2h ago  Stocks Weaker for Fifth Day as U.S. 10-Year De...
# 5             1h ago  Stocks Close Mixed; Dow Industrials End a Losi...
# 6           April 24                                Business Highlights
# 7           April 24           How Major US Stock Indexes Fared Tuesday
# 8           April 24  Caterpillar Shares Slide; Trump Steel Tariffs ...
# 9           April 24  Grumpy Investors Can’t Find Anything to Look F...
# 10          April 24  Markets Right Now: Big Tech, Industrials Lead ...
# 11          April 24  Wall Street Slides as High Bond Yields Fan Cos...
# ...

# %%
News_df.to_csv('NYTIMES(april-2018 to august-2017.csv')
