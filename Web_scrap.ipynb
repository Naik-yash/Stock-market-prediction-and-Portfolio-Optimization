# %%
import time
import random
from selenium import webdriver
import csv
from selenium.webdriver.support.select import Select
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd
from bs4 import BeautifulSoup

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--incognito")
driver = webdriver.Chrome(executable_path=r'/Users/aniketmuluk/Downloads/chromedriver',chrome_options=chrome_options)


driver.get('https://query.nytimes.com/search/sitesearch/#/dow+jones/30days/')






def get_summary_data(soup):
    soup1 = soup
    Summary1 = []
    for p in soup.find_all('p'):
            Summary1.append(p.get_text())
            
    return Summary1

a = 0
b = []
for a in range (6):
    data_div = driver.find_element_by_id('searchResults')
    data_html = data_div.get_attribute('innerHTML')
    soup = BeautifulSoup(data_html, 'html5lib')
    b.append(get_summary_data(soup))
    Next_element = driver.find_element_by_class_name('next')
    Next_element.click()
    time.sleep(15)
    soup = None
    a = a+1
    

b.remove(b[1])

import pandas as pd
df = pd.DataFrame(b)

print(df)
# Out:
#                                                    0  \
# 0  The S&P 500 and the Dow Jones Industrial Avera...
# 1  The S&P 500 ended slightly lower on Thursday a...
# 2  U.S. stocks edged higher Friday as gains from ...
# 3  Oil prices finished the week at a gain after a...
# 4  Stock markets across the globe rose the most i...
#
#                                                    1  \
# 0  Facebook plunged to its worst loss in four yea...
# 1  To celebrate the bull market's ninth birthday ...
# 2  Asian stock markets were mixed Monday followin...
# 3
# 4  The CNBC commentator, who would replace the fo...
#
#                                                    2  \
# 0  U.S. stocks were split Monday as technology co...
# 1  The S&P 500 and the Dow Industrials rose on Fr...
# 2  U.S. stocks ended slightly lower on Wednesday,...
# 3
# 4
#
#                                                    3  \
# 0  Stocks bounced up and down Tuesday as retailer...
# 1  Stocks opened lower after President Trump’s to...
# 2  Wall Street's major indexes fell on Tuesday as...
# 3  U.S. stocks sank on Monday, with the Dow Jones...
# 4  Stocks finished mostly lower Thursday in anoth...
#
#                                                    4  \
# 0  A seven-day surge in technology stocks ended T...
# 1  U.S. stocks fell on Wednesday after President ...
# 2  Cheerios cereal maker General Mills Inc said a...
# 3
# 4  Stock indexes finished mostly higher after a d...
#
#                                                    5  \
# 0  After a jittery afternoon of trading, major U....
# 1  British shares gave up early gains and finishe...
# 2  U.S. stocks advanced modestly on Tuesday as hi...
# 3
# 4
#
#                                                    6  \
# 0  U.S. stocks edged higher Friday as gains from ...
# 1  At a time when volatility in financial markets...
# 2  U.S. stocks dropped on Monday, with the S&P an...
# 3
# 4  U.S. retail sales fell for a third straight mo...
#
#                                                    7  \
# 0  Stocks finished mostly lower Thursday in anoth...
# 1  Asian shares slumped Tuesday, as pessimism fol...
# 2  After a jittery afternoon of trading, major U....
# 3  U.S. employers went on a hiring binge in Febru...
# 4
#
#                                                    8  \
# 0  U.S. stocks sank again Wednesday as investors ...
# 1  Asian shares fell Wednesday, taking their cue ...
# 2  The maneuver is good for companies’ stock pric...
# 3  Stock markets across the globe rose the most i...
# 4  As a massive manufacturing exporter, the aeros...
#
#                                                    9
# 0  Wall Street got exactly what it wanted from Fr...
# 1  The Nasdaq blasted through a record high on Fr...
# 2
# 3  The head of Boeing Co said on Thursday the U.S...
# 4  U.S. stocks were split Monday as technology co...

# %%
df.to_csv('News Data.csv')
